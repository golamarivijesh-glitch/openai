# %% [markdown]
# #### Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv

load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")
if not openai_api_key:
    raise ValueError("OPENAI_API_KEY is not set. Add it to your environment or .env file.")
os.environ["OPENAI_API_KEY"] = openai_api_key

langchain_api_key = os.getenv("LANGCHAIN_API_KEY")
if langchain_api_key:
    os.environ["LANGCHAIN_API_KEY"] = langchain_api_key

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x0000012523163380> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000012523163E00> root_client=<openai.OpenAI object at 0x00000125231601A0> root_async_client=<openai.AsyncOpenAI object at 0x0000012523163B60> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
## Input and get response form LLM

result=llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a category of artificial intelligence that involves creating models or systems capable of generating new content. This content can range from text, images, music, to even more complex data constructs, mimicking the vast diversity found in human-created content. \n\nGenerative AI models typically rely on complex algorithms, such as neural networks, to discern and replicate patterns within existing data. One of the most prominent approaches in this area involves Generative Adversarial Networks (GANs), where two neural networks—the generator and the discriminator—compete against each other to produce increasingly convincing data outputs. Another common approach is the use of transformer-based models, such as GPT (Generative Pre-trained Transformer), which excel particularly in text generation tasks.\n\nApplications of generative AI are vast and growing, with uses in content creation, design, gaming, virtual simulation, personalized recommendation systems, healthcare (e.g., drug discovery), and even in enhancing business operations through predictive analytics and decision support systems. Despite its potential benefits, generative AI also raises important ethical and security considerations, such as the need to mitigate biases, ensure data privacy, and address the potential for misuse in creating misleading information (deepfakes).' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 239, 'prompt_tokens': 13, 'total_tokens': 252, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_11da807510', 'id': 'chatcmpl-DMmVYoOioHt6MD4lA2KgTHeD1eRqH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d1dd5-e95c-7373-9ece-ffeaa6ff1fe8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 239, 'total_tokens': 252, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content="Langsmith is a comprehensive tool suite developed to enhance the creation, assessment, and refinement of applications built on language models. It introduces a platform-agnostic approach, allowing developers to work with any Large Language Model (LLM) or integration framework, not limited to LangChain alone. Langsmith's core capabilities include real-time logging, tracing, and debugging of language model interactions, offering detailed insights into prompt and response flows.\n\nIt also provides dataset management features, enabling developers to efficiently organize and utilize data for model evaluation. Built-in metrics and testing functionalities empower users to evaluate and iterate on their models with precision. Additionally, Langsmith features advanced error analysis tools, allowing for a deep dive into model outputs to identify patterns, anomalies, and areas for improvement. This suite is particularly valuable for developers aiming to build robust, high-performance language model applications." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 169, 'prompt_tokens': 33, 'total_tokens': 202, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_11da807510', 'id': 'chatcmpl-DMmVeu0vChXFriQ009x5oC1zNE22h', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d1dd6-0011-7fc2-a1e8-f4853da8b5d9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 33, 'output_tokens': 169, 'total_tokens': 202, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a tool developed by LangChain that is designed to enhance the development and optimization of applications utilizing large language models (LLMs). It offers a robust platform for the testing and monitoring of generative AI applications. Langsmith provides features for tracing, debugging, and analyzing interactions with LLMs, making it easier for developers to understand and improve the behavior of their applications. Additionally, it includes evaluation tools to assess the performance of language models, facilitating experimentation with different prompts, parameter settings, and even model versions to optimize outputs. Overall, Langsmith streamlines the workflow of building more reliable and effective AI-driven applications.
